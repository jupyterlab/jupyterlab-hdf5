# %%
# %matplotlib inline

import h5py
from matplotlib import pyplot as plt
import pandas as pd
import os

# %% [markdown]
# ### Pre-filled example

# %%
with h5py.File(os.path.expanduser("~/git/jupyterlab-hdf/example/nested_int_data_ext.hdf5"), 'r') as f:
    data = f["/leaf01/data01.data"]
    plt.plot(data[:100, 3], data[:100, 17])
